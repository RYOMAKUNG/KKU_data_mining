# %% [markdown]
# <a href="https://colab.research.google.com/github/RYOMAKUNG/KKU_data_mining/blob/master/data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab  import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
import pandas as pd

# %%
base_path='/content/drive/My Drive/DWDM_material'

# %%
data = pd.read_csv(os.path.join(base_path,'test.csv'))

# %%
print(data)
# Out:
#      Unnamed: 0        x        y
# 0             0  55.3846  97.1795
# 1             1  51.5385  96.0256
# 2             2  46.1538  94.4872
# 3             3  42.8205  91.4103
# 4             4  40.7692  88.3333
# ..          ...      ...      ...
# 137         137  39.4872  25.3846
# 138         138  91.2821  41.5385
# 139         139  50.0000  95.7692
# 140         140  47.9487  95.0000
# 141         141  44.1026  92.6923
#
# [142 rows x 3 columns]

# %% [markdown]
# ##Box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['y'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f59afe22a58>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f59afdbb4a8>,
#   <matplotlib.lines.Line2D at 0x7f59afdbb828>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f59afdbbf28>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f59afdbbba8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f59afe22d68>,
#   <matplotlib.lines.Line2D at 0x7f59afdbb128>]}

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f59af8f0b38>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f59af8fd588>,
#   <matplotlib.lines.Line2D at 0x7f59af8fd908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f59af907048>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f59af8fdc88>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f59af8f0e48>,
#   <matplotlib.lines.Line2D at 0x7f59af8fd208>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f59af86f7b8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f59af87a208>,
#   <matplotlib.lines.Line2D at 0x7f59af87a588>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f59af87ac88>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f59af87a908>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f59af86fac8>,
#   <matplotlib.lines.Line2D at 0x7f59af86fe48>]}

# %% [markdown]
# ##scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k',marker='p')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k',marker='p',alpha=0.1)
plt.scatter([22,23],[60,62],alpha=0.4)
